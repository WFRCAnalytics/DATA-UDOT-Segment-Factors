# %% [markdown]
# # Input Data, Variables, and Parameters

# %%
import numpy as np
import os
import pandas as pd
import arcpy

# Import the required ArcGIS API for Python modules
import arcgis
from arcgis.gis import GIS
gis = arcgis.GIS()
from arcgis.geoanalytics import manage_data

from IPython.display import display, Markdown

strSegments = r"input\master\Segments-WF-v901-2024-02-20.shp"
strGeographies = r"arcgis\SegmentsGeographyUpdate\Geographies\FactorGeographies_20210824.shp"
strMasterNetworkWFRC = r"_wfrc\MasterNet_v901_2024-02-20.csv"

# %%
dirWork         = os.getcwd()
dirInput        = os.path.join(dirWork, r'input'         )
dirIntermediate = os.path.join(dirWork, r'intermediate'  )
dirResults      = os.path.join(dirWork, r'results'       )
dirParams       = os.path.join(dirWork, r'params'        )
dirWebApp       = os.path.join(dirResults, r'webapp_data')

#for the geography shapefile, what are all the column names for the various factor geographies
#lGeoFieldNames  = ['WDFACGEO','SSNFACGEO','COFACGEO']
lGeoFieldNames  = ['COFACGEO'] # for update only get combined factors

# %%
ProcessGDB = "process.gdb"

#name of new data features
fcTAZAreaType         = os.path.join(dirIntermediate, ProcessGDB + "\TAZAreaType"                 )
fcAreaType            = os.path.join(dirIntermediate, ProcessGDB + "\AreaType"                    )
fcAreaTypeSegment     = os.path.join(dirIntermediate, ProcessGDB + "\AreaTypeSegmentIntersect"    )
fcSegmentsWithAADT    = os.path.join(dirIntermediate, ProcessGDB + "\SegmentsWithAADT"            )
fcGeographies         = os.path.join(dirIntermediate, ProcessGDB + "\Geographies"                 )
#changed to being programmatically defined
#fcSegmentsGeographies = os.path.join(dirIntermediate, ProcessGDB + "\SegmentsGeographiesIntersect")

def deleteIfExists(obj):
    if arcpy.Exists(obj): arcpy.Delete_management(obj)

#if processing geodatabase doesn't exist, create it
print("Checking if " + ProcessGDB + " exists...")
if not arcpy.Exists(os.path.join(dirIntermediate, ProcessGDB)):
    print("Creating " + ProcessGDB + "...")
    arcpy.management.CreateFileGDB(dirIntermediate, ProcessGDB)
else:
    print(ProcessGDB + " exists...")
# Out:
# Checking if process.gdb exists...
# process.gdb exists...

# %%
#read segment files
sdfSegmentsAll      = pd.DataFrame.spatial.from_featureclass(os.path.join(dirWork, strSegments))

#All SegIDs
dfAllSegIDs = sdfSegmentsAll[['SEGID']]

#read factor geographies
sdfGeographies = pd.DataFrame.spatial.from_featureclass(os.path.join(dirWork, strGeographies))

# %%
#CHECK FOR DUPLICATE SEGIDs
_df = sdfSegmentsAll.groupby(['SEGID'], as_index=False).agg(COUNT=('SEGID','count'))
_df[_df['COUNT']>1]
# Out:
#            SEGID  COUNT
# 62    0015_266.5      4
# 1542  1446_000.0      4
# 2898  2831_000.0      4
# 3968    MAG_6044      4
# 4133    MAG_6215      4
# 4180    MAG_6263      4
# 4232    MAG_6315      4
# 4236    MAG_6319      4

# %%
#areatype overrides - filename only here, so that it can be an iterative process later in the notebook
fnATOverride = os.path.join(dirParams, r'area_type_overrides_segments.csv')

#functional type group overrides - filename only here, so that it can be an iterative process later in the notebook
fnFTGroupOverride = os.path.join(dirParams, r'functional_type_group_overrides.csv')

#read parameter tables
#csv: , parse_dates=['DATEFROM','DATETO']
prmVolumeGroups                           = pd.read_csv(os.path.join(dirParams, r'volume_groups.csv'                             )                      )
prmFacGrpVolClassToVolGrp                 = pd.read_csv(os.path.join(dirParams, r'facgroup_volume_class_to_volume_group.csv'     )                      )
prmStationGrpToFacGrpFields               = pd.read_csv(os.path.join(dirParams, r'station_group_to_facgroup.csv'                 )                      )
prmStationGrpToFacGrpFieldsFacGeoOverride = pd.read_csv(os.path.join(dirParams, r'station_group_to_facgroup_facgeo_overrides.csv'),dtype = {'ROUTE':str})
prmFacATGrpToAreaType                     = pd.read_csv(os.path.join(dirParams, r'area_type_group_to_area_type.csv'              )                      )

# filter by groupings we're only going to use in this update: lGeoFieldNames
prmStationGrpToFacGrpFields = prmStationGrpToFacGrpFields[prmStationGrpToFacGrpFields['FACGEOGROUP'].isin(lGeoFieldNames)]
prmStationGrpToFacGrpFieldsFacGeoOverride = prmStationGrpToFacGrpFieldsFacGeoOverride[prmStationGrpToFacGrpFieldsFacGeoOverride['FACGEOGROUP'].isin(lGeoFieldNames)]

# %%
# read USTM taz / urbanization / network
sdfTAZ = pd.DataFrame.spatial.from_featureclass(os.path.join(dirInput, r"USTM_v3.0 - 2023-08-17_DRAFT_Data\BY_2019\TAZ.shp"))
dfUrbanization = pd.read_csv(os.path.join(dirInput, r"USTM_v3.0 - 2023-08-17_DRAFT_Data\BY_2019\Urbanization_BY2019.csv"),low_memory=False)
dfUSTMMasterNetwork = pd.read_csv(os.path.join(dirInput, r"USTM_v3.0 - 2023-08-17_DRAFT_Data\USTMv3_MasterNet_Snapped_20230817_Link.csv"),low_memory=False)

# read WFRC network
dfWFRCMasterNetwork = pd.read_csv(os.path.join(dirInput, strMasterNetworkWFRC),low_memory=False)

# %%
#read processed data
dfCCSFactors = pd.read_csv(os.path.join(dirIntermediate, r'CCS_Factors_AllGroupings.csv'))

# %% [markdown]
# # Prepare Factor Group Lookup Table

# %%
prmFacGrpVolClassToVolGrp
# Out:
#                         FACGRP   FACVOLCLASS  VOLUMEGROUP
# 0                    Southeast   1-LowVolume   SERuralLow
# 1                    Southeast   2-MidVolume   SERuralMid
# 2  StatewideArterialExpressway   1-LowVolume   UTRuralLow
# 3  StatewideArterialExpressway   2-MidVolume   UTRuralMid
# 4  StatewideArterialExpressway  3-HighVolume  UTRuralHigh

# %%
prmVolumeGroups
# Out:
#    VOLUMEGROUP  VOLUMEFROM  VOLUMETO
# 0          All           0   1000000
# 1   SERuralLow           0      1500
# 2   SERuralMid        1500   1000000
# 3   UTRuralLow           0      2500
# 4   UTRuralMid        2500     12500
# 5  UTRuralHigh       12500   1000000

# %%
prmStationGrpToFacGrpFields
# Out:
#    FACGEOGROUP STATIONGROUP                FACGRP              FACATGROUP  \
# 35    COFACGEO          COA     I80NevSR36Freeway          0-AllAreaTypes
# 36    COFACGEO          COB   I80SR36SR154Freeway          0-AllAreaTypes
# 37    COFACGEO          COC  I80SR154SR186Freeway          0-AllAreaTypes
# 38    COFACGEO          COD   I80SR186US40Freeway          0-AllAreaTypes
# 39    COFACGEO          COY     I80US40WyoFreeway          0-AllAreaTypes
# ..         ...          ...                   ...                     ...
# 67    COFACGEO          CO5            I15Freeway            2-Transition
# 68    COFACGEO          CO6            I15Freeway  345-Suburban/Urban/CBD
# 69    COFACGEO          CO8           I215Freeway          0-AllAreaTypes
# 70    COFACGEO          CO9            I70Freeway          0-AllAreaTypes
# 71    COFACGEO          XX3      StatewideFreeway          0-AllAreaTypes
#
#      FACVOLCLASS
# 35  0-AllVolumes
# 36  0-AllVolumes
# 37  0-AllVolumes
# 38  0-AllVolumes
# 39  0-AllVolumes
# ..           ...
# 67  0-AllVolumes
# 68  0-AllVolumes
# 69  0-AllVolumes
# 70  0-AllVolumes
# 71  0-AllVolumes
#
# [37 rows x 5 columns]

# %%
#default
prmStationGrpToFacGrpFields['FTCOMBOGROUP'] = 'ArterialExpressway'
prmStationGrpToFacGrpFields['FACGEO'] = ''

#split up FACGRP value into two fields
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('ArterialExpressway'),'FTCOMBOGROUP'] = 'ArterialExpressway'
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('ArterialExpressway'),'FACGEO'] = prmStationGrpToFacGrpFields['FACGRP'].str.replace('ArterialExpressway', '', regex=False)
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Freeway'),'FTCOMBOGROUP'] = 'Freeway'
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Freeway'),'FACGEO'] = prmStationGrpToFacGrpFields['FACGRP'].str.replace('Freeway', '', regex=False)
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Arterial') & -(prmStationGrpToFacGrpFields['FACGRP'].str.contains('Expressway')),'FTCOMBOGROUP'] = 'Arterial'
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Arterial') & -(prmStationGrpToFacGrpFields['FACGRP'].str.contains('Expressway')),'FACGEO'] = prmStationGrpToFacGrpFields['FACGRP'].str.replace('Arterial', '', regex=False)
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Expressway') & -(prmStationGrpToFacGrpFields['FACGRP'].str.contains('Arterial')),'FTCOMBOGROUP'] = 'Expressway'
prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGRP'].str.contains('Expressway') & -(prmStationGrpToFacGrpFields['FACGRP'].str.contains('Arterial')),'FACGEO'] = prmStationGrpToFacGrpFields['FACGRP'].str.replace('Expressway', '', regex=False)

prmStationGrpToFacGrpFields.loc[prmStationGrpToFacGrpFields['FACGEO']=='','FACGEO'] = prmStationGrpToFacGrpFields['FACGRP']

prmStationGrpToFacGrpFields
# Out:
#    FACGEOGROUP STATIONGROUP                FACGRP              FACATGROUP  \
# 35    COFACGEO          COA     I80NevSR36Freeway          0-AllAreaTypes
# 36    COFACGEO          COB   I80SR36SR154Freeway          0-AllAreaTypes
# 37    COFACGEO          COC  I80SR154SR186Freeway          0-AllAreaTypes
# 38    COFACGEO          COD   I80SR186US40Freeway          0-AllAreaTypes
# 39    COFACGEO          COY     I80US40WyoFreeway          0-AllAreaTypes
# ..         ...          ...                   ...                     ...
# 67    COFACGEO          CO5            I15Freeway            2-Transition
# 68    COFACGEO          CO6            I15Freeway  345-Suburban/Urban/CBD
# 69    COFACGEO          CO8           I215Freeway          0-AllAreaTypes
# 70    COFACGEO          CO9            I70Freeway          0-AllAreaTypes
# 71    COFACGEO          XX3      StatewideFreeway          0-AllAreaTypes
#
#      FACVOLCLASS FTCOMBOGROUP         FACGEO
# 35  0-AllVolumes      Freeway     I80NevSR36
# 36  0-AllVolumes      Freeway   I80SR36SR154
# 37  0-AllVolumes      Freeway  I80SR154SR186
# 38  0-AllVolumes      Freeway   I80SR186US40
# 39  0-AllVolumes      Freeway     I80US40Wyo
# ..           ...          ...            ...
# 67  0-AllVolumes      Freeway            I15
# 68  0-AllVolumes      Freeway            I15
# 69  0-AllVolumes      Freeway           I215
# 70  0-AllVolumes      Freeway            I70
# 71  0-AllVolumes      Freeway      Statewide
#
# [37 rows x 7 columns]

# %%
#split up combined FT Groups

dFTComboToFTGroup = {
     'FTCOMBOGROUP' : ['Arterial','Expressway','Freeway','ArterialExpressway','ArterialExpressway','ExpresswayFreeway','ExpresswayFreeway'],
     'FTGROUP':       ['Arterial','Expressway','Freeway','Arterial'          ,'Expressway'        ,'Expressway'       ,'Freeway'          ]
}
dfFTComboToFTGroup = pd.DataFrame(dFTComboToFTGroup)
display(dfFTComboToFTGroup)

prmStationGrpToFacGrpFields = pd.DataFrame.merge(prmStationGrpToFacGrpFields,dfFTComboToFTGroup,on='FTCOMBOGROUP')
display(prmStationGrpToFacGrpFields)
# Out:
#          FTCOMBOGROUP     FTGROUP
# 0            Arterial    Arterial
# 1          Expressway  Expressway
# 2             Freeway     Freeway
# 3  ArterialExpressway    Arterial
# 4  ArterialExpressway  Expressway
# 5   ExpresswayFreeway  Expressway
# 6   ExpresswayFreeway     Freeway
#    FACGEOGROUP STATIONGROUP                FACGRP      FACATGROUP  \
# 0     COFACGEO          COA     I80NevSR36Freeway  0-AllAreaTypes
# 1     COFACGEO          COB   I80SR36SR154Freeway  0-AllAreaTypes
# 2     COFACGEO          COC  I80SR154SR186Freeway  0-AllAreaTypes
# 3     COFACGEO          COD   I80SR186US40Freeway  0-AllAreaTypes
# 4     COFACGEO          COY     I80US40WyoFreeway  0-AllAreaTypes
# ..         ...          ...                   ...             ...
# 49    COFACGEO          CO2         BigCottonwood  0-AllAreaTypes
# 50    COFACGEO          CO3           CedarBreaks  0-AllAreaTypes
# 51    COFACGEO          CO3           CedarBreaks  0-AllAreaTypes
# 52    COFACGEO          COV    WashingtonArterial  0-AllAreaTypes
# 53    COFACGEO          COW  WashingtonExpressway  0-AllAreaTypes
#
#      FACVOLCLASS        FTCOMBOGROUP         FACGEO     FTGROUP
# 0   0-AllVolumes             Freeway     I80NevSR36     Freeway
# 1   0-AllVolumes             Freeway   I80SR36SR154     Freeway
# 2   0-AllVolumes             Freeway  I80SR154SR186     Freeway
# 3   0-AllVolumes             Freeway   I80SR186US40     Freeway
# 4   0-AllVolumes             Freeway     I80US40Wyo     Freeway
# ..           ...                 ...            ...         ...
# 49  0-AllVolumes  ArterialExpressway  BigCottonwood  Expressway
# 50  0-AllVolumes  ArterialExpressway    CedarBreaks    Arterial
# 51  0-AllVolumes  ArterialExpressway    CedarBreaks  Expressway
# 52  0-AllVolumes            Arterial     Washington    Arterial
# 53  0-AllVolumes          Expressway     Washington  Expressway
#
# [54 rows x 8 columns]

# %%
prmStationGrpToFacGrpFieldsAT = pd.DataFrame.merge(prmStationGrpToFacGrpFields,prmFacATGrpToAreaType,on='FACATGROUP')
prmStationGrpToFacGrpFieldsAT
# Out:
#     FACGEOGROUP STATIONGROUP                       FACGRP      FACATGROUP  \
# 0      COFACGEO          COA            I80NevSR36Freeway  0-AllAreaTypes
# 1      COFACGEO          COA            I80NevSR36Freeway  0-AllAreaTypes
# 2      COFACGEO          COA            I80NevSR36Freeway  0-AllAreaTypes
# 3      COFACGEO          COA            I80NevSR36Freeway  0-AllAreaTypes
# 4      COFACGEO          COA            I80NevSR36Freeway  0-AllAreaTypes
# ..          ...          ...                          ...             ...
# 209    COFACGEO          COT  StatewideArterialExpressway      3-Suburban
# 210    COFACGEO          COU  StatewideArterialExpressway    45-Urban/CBD
# 211    COFACGEO          COU  StatewideArterialExpressway    45-Urban/CBD
# 212    COFACGEO          COU  StatewideArterialExpressway    45-Urban/CBD
# 213    COFACGEO          COU  StatewideArterialExpressway    45-Urban/CBD
#
#       FACVOLCLASS        FTCOMBOGROUP      FACGEO     FTGROUP  AREATYPE
# 0    0-AllVolumes             Freeway  I80NevSR36     Freeway         1
# 1    0-AllVolumes             Freeway  I80NevSR36     Freeway         2
# 2    0-AllVolumes             Freeway  I80NevSR36     Freeway         3
# 3    0-AllVolumes             Freeway  I80NevSR36     Freeway         4
# 4    0-AllVolumes             Freeway  I80NevSR36     Freeway         5
# ..            ...                 ...         ...         ...       ...
# 209  0-AllVolumes  ArterialExpressway   Statewide  Expressway         3
# 210  0-AllVolumes  ArterialExpressway   Statewide    Arterial         4
# 211  0-AllVolumes  ArterialExpressway   Statewide    Arterial         5
# 212  0-AllVolumes  ArterialExpressway   Statewide  Expressway         4
# 213  0-AllVolumes  ArterialExpressway   Statewide  Expressway         5
#
# [214 rows x 9 columns]

# %%
dfFacFieldLookup = pd.DataFrame.merge(prmStationGrpToFacGrpFields,prmFacGrpVolClassToVolGrp,on=('FACGRP','FACVOLCLASS'),how='left')
dfFacFieldLookup.loc[(dfFacFieldLookup['FACVOLCLASS']=="0-AllVolumes"), 'VOLUMEGROUP'] = 'All'
dfFacFieldLookup = pd.DataFrame.merge(dfFacFieldLookup,prmVolumeGroups,on='VOLUMEGROUP')
dfFacFieldLookup = pd.DataFrame.merge(dfFacFieldLookup,prmFacATGrpToAreaType,on='FACATGROUP')
dfFacFieldLookup = dfFacFieldLookup[['FACGEO','FTGROUP','AREATYPE','VOLUMEFROM','VOLUMETO','STATIONGROUP','FACGEOGROUP']]
dfFacFieldLookup = dfFacFieldLookup.sort_values(by=['FACGEO','FTGROUP','AREATYPE','VOLUMEFROM','VOLUMETO','STATIONGROUP'])
pd.set_option('display.max_rows', dfFacFieldLookup.shape[0]+1)
display(dfFacFieldLookup)
pd.set_option('display.max_rows', 10)
# Out:
#                          FACGEO     FTGROUP  AREATYPE  VOLUMEFROM  VOLUMETO  \
# 125                  AlpineLoop    Arterial         1           0   1000000
# 126                  AlpineLoop    Arterial         2           0   1000000
# 127                  AlpineLoop    Arterial         3           0   1000000
# 128                  AlpineLoop    Arterial         4           0   1000000
# 129                  AlpineLoop    Arterial         5           0   1000000
# 130                  AlpineLoop  Expressway         1           0   1000000
# 131                  AlpineLoop  Expressway         2           0   1000000
# 132                  AlpineLoop  Expressway         3           0   1000000
# 133                  AlpineLoop  Expressway         4           0   1000000
# 134                  AlpineLoop  Expressway         5           0   1000000
# 135                    BearLake    Arterial         1           0   1000000
# 136                    BearLake    Arterial         2           0   1000000
# 137                    BearLake    Arterial         3           0   1000000
# 138                    BearLake    Arterial         4           0   1000000
# 139                    BearLake    Arterial         5           0   1000000
# 140                    BearLake  Expressway         1           0   1000000
# 141                    BearLake  Expressway         2           0   1000000
# 142                    BearLake  Expressway         3           0   1000000
# 143                    BearLake  Expressway         4           0   1000000
# 144                    BearLake  Expressway         5           0   1000000
# 145               BigCottonwood    Arterial         1           0   1000000
# 146               BigCottonwood    Arterial         2           0   1000000
# 147               BigCottonwood    Arterial         3           0   1000000
# 148               BigCottonwood    Arterial         4           0   1000000
# 149               BigCottonwood    Arterial         5           0   1000000
# 150               BigCottonwood  Expressway         1           0   1000000
# 151               BigCottonwood  Expressway         2           0   1000000
# 152               BigCottonwood  Expressway         3           0   1000000
# 153               BigCottonwood  Expressway         4           0   1000000
# 154               BigCottonwood  Expressway         5           0   1000000
# 155                 CedarBreaks    Arterial         1           0   1000000
# 156                 CedarBreaks    Arterial         2           0   1000000
# 157                 CedarBreaks    Arterial         3           0   1000000
# 158                 CedarBreaks    Arterial         4           0   1000000
# 159                 CedarBreaks    Arterial         5           0   1000000
# 160                 CedarBreaks  Expressway         1           0   1000000
# 161                 CedarBreaks  Expressway         2           0   1000000
# 162                 CedarBreaks  Expressway         3           0   1000000
# 163                 CedarBreaks  Expressway         4           0   1000000
# 164                 CedarBreaks  Expressway         5           0   1000000
# 195                         I15     Freeway         1           0   1000000
# 202                         I15     Freeway         2           0   1000000
# 205                         I15     Freeway         3           0   1000000
# 206                         I15     Freeway         4           0   1000000
# 207                         I15     Freeway         5           0   1000000
# 55                  I15Plymouth     Freeway         1           0   1000000
# 56                  I15Plymouth     Freeway         2           0   1000000
# 57                  I15Plymouth     Freeway         3           0   1000000
# 58                  I15Plymouth     Freeway         4           0   1000000
# 59                  I15Plymouth     Freeway         5           0   1000000
# 60                         I215     Freeway         1           0   1000000
# 61                         I215     Freeway         2           0   1000000
# 62                         I215     Freeway         3           0   1000000
# 63                         I215     Freeway         4           0   1000000
# 64                         I215     Freeway         5           0   1000000
# 65                          I70     Freeway         1           0   1000000
# 66                          I70     Freeway         2           0   1000000
# 67                          I70     Freeway         3           0   1000000
# 68                          I70     Freeway         4           0   1000000
# 69                          I70     Freeway         5           0   1000000
# 0                    I80NevSR36     Freeway         1           0   1000000
# 1                    I80NevSR36     Freeway         2           0   1000000
# 2                    I80NevSR36     Freeway         3           0   1000000
# 3                    I80NevSR36     Freeway         4           0   1000000
# 4                    I80NevSR36     Freeway         5           0   1000000
# 10                I80SR154SR186     Freeway         1           0   1000000
# 11                I80SR154SR186     Freeway         2           0   1000000
# 12                I80SR154SR186     Freeway         3           0   1000000
# 13                I80SR154SR186     Freeway         4           0   1000000
# 14                I80SR154SR186     Freeway         5           0   1000000
# 15                 I80SR186US40     Freeway         1           0   1000000
# 16                 I80SR186US40     Freeway         2           0   1000000
# 17                 I80SR186US40     Freeway         3           0   1000000
# 18                 I80SR186US40     Freeway         4           0   1000000
# 19                 I80SR186US40     Freeway         5           0   1000000
# 5                  I80SR36SR154     Freeway         1           0   1000000
# 6                  I80SR36SR154     Freeway         2           0   1000000
# 7                  I80SR36SR154     Freeway         3           0   1000000
# 8                  I80SR36SR154     Freeway         4           0   1000000
# 9                  I80SR36SR154     Freeway         5           0   1000000
# 20                   I80US40Wyo     Freeway         1           0   1000000
# 21                   I80US40Wyo     Freeway         2           0   1000000
# 22                   I80US40Wyo     Freeway         3           0   1000000
# 23                   I80US40Wyo     Freeway         4           0   1000000
# 24                   I80US40Wyo     Freeway         5           0   1000000
# 30                      I84East     Freeway         1           0   1000000
# 31                      I84East     Freeway         2           0   1000000
# 32                      I84East     Freeway         3           0   1000000
# 33                      I84East     Freeway         4           0   1000000
# 34                      I84East     Freeway         5           0   1000000
# 25                      I84West     Freeway         1           0   1000000
# 26                      I84West     Freeway         2           0   1000000
# 27                      I84West     Freeway         3           0   1000000
# 28                      I84West     Freeway         4           0   1000000
# 29                      I84West     Freeway         5           0   1000000
# 35                       Legacy     Freeway         1           0   1000000
# 36                       Legacy     Freeway         2           0   1000000
# 37                       Legacy     Freeway         3           0   1000000
# 38                       Legacy     Freeway         4           0   1000000
# 39                       Legacy     Freeway         5           0   1000000
# 75    LittleCottonwoodSnowbasin    Arterial         1           0   1000000
# 76    LittleCottonwoodSnowbasin    Arterial         2           0   1000000
# 77    LittleCottonwoodSnowbasin    Arterial         3           0   1000000
# 78    LittleCottonwoodSnowbasin    Arterial         4           0   1000000
# 79    LittleCottonwoodSnowbasin    Arterial         5           0   1000000
# 80    LittleCottonwoodSnowbasin  Expressway         1           0   1000000
# 81    LittleCottonwoodSnowbasin  Expressway         2           0   1000000
# 82    LittleCottonwoodSnowbasin  Expressway         3           0   1000000
# 83    LittleCottonwoodSnowbasin  Expressway         4           0   1000000
# 84    LittleCottonwoodSnowbasin  Expressway         5           0   1000000
# 85                         Moab    Arterial         1           0   1000000
# 86                         Moab    Arterial         2           0   1000000
# 87                         Moab    Arterial         3           0   1000000
# 88                         Moab    Arterial         4           0   1000000
# 89                         Moab    Arterial         5           0   1000000
# 90                         Moab  Expressway         1           0   1000000
# 91                         Moab  Expressway         2           0   1000000
# 92                         Moab  Expressway         3           0   1000000
# 93                         Moab  Expressway         4           0   1000000
# 94                         Moab  Expressway         5           0   1000000
# 95                     ParkCity    Arterial         1           0   1000000
# 96                     ParkCity    Arterial         2           0   1000000
# 97                     ParkCity    Arterial         3           0   1000000
# 98                     ParkCity    Arterial         4           0   1000000
# 99                     ParkCity    Arterial         5           0   1000000
# 100                    ParkCity  Expressway         1           0   1000000
# 101                    ParkCity  Expressway         2           0   1000000
# 102                    ParkCity  Expressway         3           0   1000000
# 103                    ParkCity  Expressway         4           0   1000000
# 104                    ParkCity  Expressway         5           0   1000000
# 105              RuralRecLowVol    Arterial         1           0   1000000
# 106              RuralRecLowVol    Arterial         2           0   1000000
# 107              RuralRecLowVol    Arterial         3           0   1000000
# 108              RuralRecLowVol    Arterial         4           0   1000000
# 109              RuralRecLowVol    Arterial         5           0   1000000
# 110              RuralRecLowVol  Expressway         1           0   1000000
# 111              RuralRecLowVol  Expressway         2           0   1000000
# 112              RuralRecLowVol  Expressway         3           0   1000000
# 113              RuralRecLowVol  Expressway         4           0   1000000
# 114              RuralRecLowVol  Expressway         5           0   1000000
# 115  RuralRecLowVolWinterClosed    Arterial         1           0   1000000
# 116  RuralRecLowVolWinterClosed    Arterial         2           0   1000000
# 117  RuralRecLowVolWinterClosed    Arterial         3           0   1000000
# 118  RuralRecLowVolWinterClosed    Arterial         4           0   1000000
# 119  RuralRecLowVolWinterClosed    Arterial         5           0   1000000
# 120  RuralRecLowVolWinterClosed  Expressway         1           0   1000000
# 121  RuralRecLowVolWinterClosed  Expressway         2           0   1000000
# 122  RuralRecLowVolWinterClosed  Expressway         3           0   1000000
# 123  RuralRecLowVolWinterClosed  Expressway         4           0   1000000
# 124  RuralRecLowVolWinterClosed  Expressway         5           0   1000000
# 40                        SR201     Freeway         1           0   1000000
# 41                        SR201     Freeway         2           0   1000000
# 42                        SR201     Freeway         3           0   1000000
# 43                        SR201     Freeway         4           0   1000000
# 44                        SR201     Freeway         5           0   1000000
# 175                   Southeast    Arterial         1           0      1500
# 185                   Southeast    Arterial         1        1500   1000000
# 176                   Southeast    Arterial         2           0      1500
# 186                   Southeast    Arterial         2        1500   1000000
# 177                   Southeast    Arterial         3           0      1500
# 187                   Southeast    Arterial         3        1500   1000000
# 178                   Southeast    Arterial         4           0      1500
# 188                   Southeast    Arterial         4        1500   1000000
# 179                   Southeast    Arterial         5           0      1500
# 189                   Southeast    Arterial         5        1500   1000000
# 180                   Southeast  Expressway         1           0      1500
# 190                   Southeast  Expressway         1        1500   1000000
# 181                   Southeast  Expressway         2           0      1500
# 191                   Southeast  Expressway         2        1500   1000000
# 182                   Southeast  Expressway         3           0      1500
# 192                   Southeast  Expressway         3        1500   1000000
# 183                   Southeast  Expressway         4           0      1500
# 193                   Southeast  Expressway         4        1500   1000000
# 184                   Southeast  Expressway         5           0      1500
# 194                   Southeast  Expressway         5        1500   1000000
# 196                   Statewide    Arterial         1           0      2500
# 198                   Statewide    Arterial         1        2500     12500
# 200                   Statewide    Arterial         1       12500   1000000
# 203                   Statewide    Arterial         2           0   1000000
# 208                   Statewide    Arterial         3           0   1000000
# 210                   Statewide    Arterial         4           0   1000000
# 211                   Statewide    Arterial         5           0   1000000
# 197                   Statewide  Expressway         1           0      2500
# 199                   Statewide  Expressway         1        2500     12500
# 201                   Statewide  Expressway         1       12500   1000000
# 204                   Statewide  Expressway         2           0   1000000
# 209                   Statewide  Expressway         3           0   1000000
# 212                   Statewide  Expressway         4           0   1000000
# 213                   Statewide  Expressway         5           0   1000000
# 70                    Statewide     Freeway         1           0   1000000
# 71                    Statewide     Freeway         2           0   1000000
# 72                    Statewide     Freeway         3           0   1000000
# 73                    Statewide     Freeway         4           0   1000000
# 74                    Statewide     Freeway         5           0   1000000
# 45                         US40     Freeway         1           0   1000000
# 46                         US40     Freeway         2           0   1000000
# 47                         US40     Freeway         3           0   1000000
# 48                         US40     Freeway         4           0   1000000
# 49                         US40     Freeway         5           0   1000000
# 165                  Washington    Arterial         1           0   1000000
# 166                  Washington    Arterial         2           0   1000000
# 167                  Washington    Arterial         3           0   1000000
# 168                  Washington    Arterial         4           0   1000000
# 169                  Washington    Arterial         5           0   1000000
# 170                  Washington  Expressway         1           0   1000000
# 171                  Washington  Expressway         2           0   1000000
# 172                  Washington  Expressway         3           0   1000000
# 173                  Washington  Expressway         4           0   1000000
# 174                  Washington  Expressway         5           0   1000000
# 50                   Washington     Freeway         1           0   1000000
# 51                   Washington     Freeway         2           0   1000000
# 52                   Washington     Freeway         3           0   1000000
# 53                   Washington     Freeway         4           0   1000000
# 54                   Washington     Freeway         5           0   1000000
#
#     STATIONGROUP FACGEOGROUP
# 125          CO0    COFACGEO
# 126          CO0    COFACGEO
# 127          CO0    COFACGEO
# 128          CO0    COFACGEO
# 129          CO0    COFACGEO
# 130          CO0    COFACGEO
# 131          CO0    COFACGEO
# 132          CO0    COFACGEO
# 133          CO0    COFACGEO
# 134          CO0    COFACGEO
# 135          CO1    COFACGEO
# 136          CO1    COFACGEO
# 137          CO1    COFACGEO
# 138          CO1    COFACGEO
# 139          CO1    COFACGEO
# 140          CO1    COFACGEO
# 141          CO1    COFACGEO
# 142          CO1    COFACGEO
# 143          CO1    COFACGEO
# 144          CO1    COFACGEO
# 145          CO2    COFACGEO
# 146          CO2    COFACGEO
# 147          CO2    COFACGEO
# 148          CO2    COFACGEO
# 149          CO2    COFACGEO
# 150          CO2    COFACGEO
# 151          CO2    COFACGEO
# 152          CO2    COFACGEO
# 153          CO2    COFACGEO
# 154          CO2    COFACGEO
# 155          CO3    COFACGEO
# 156          CO3    COFACGEO
# 157          CO3    COFACGEO
# 158          CO3    COFACGEO
# 159          CO3    COFACGEO
# 160          CO3    COFACGEO
# 161          CO3    COFACGEO
# 162          CO3    COFACGEO
# 163          CO3    COFACGEO
# 164          CO3    COFACGEO
# 195          CO4    COFACGEO
# 202          CO5    COFACGEO
# 205          CO6    COFACGEO
# 206          CO6    COFACGEO
# 207          CO6    COFACGEO
# 55           CO7    COFACGEO
# 56           CO7    COFACGEO
# 57           CO7    COFACGEO
# 58           CO7    COFACGEO
# 59           CO7    COFACGEO
# 60           CO8    COFACGEO
# 61           CO8    COFACGEO
# 62           CO8    COFACGEO
# 63           CO8    COFACGEO
# 64           CO8    COFACGEO
# 65           CO9    COFACGEO
# 66           CO9    COFACGEO
# 67           CO9    COFACGEO
# 68           CO9    COFACGEO
# 69           CO9    COFACGEO
# 0            COA    COFACGEO
# 1            COA    COFACGEO
# 2            COA    COFACGEO
# 3            COA    COFACGEO
# 4            COA    COFACGEO
# 10           COC    COFACGEO
# 11           COC    COFACGEO
# 12           COC    COFACGEO
# 13           COC    COFACGEO
# 14           COC    COFACGEO
# 15           COD    COFACGEO
# 16           COD    COFACGEO
# 17           COD    COFACGEO
# 18           COD    COFACGEO
# 19           COD    COFACGEO
# 5            COB    COFACGEO
# 6            COB    COFACGEO
# 7            COB    COFACGEO
# 8            COB    COFACGEO
# 9            COB    COFACGEO
# 20           COY    COFACGEO
# 21           COY    COFACGEO
# 22           COY    COFACGEO
# 23           COY    COFACGEO
# 24           COY    COFACGEO
# 30           COZ    COFACGEO
# 31           COZ    COFACGEO
# 32           COZ    COFACGEO
# 33           COZ    COFACGEO
# 34           COZ    COFACGEO
# 25           COE    COFACGEO
# 26           COE    COFACGEO
# 27           COE    COFACGEO
# 28           COE    COFACGEO
# 29           COE    COFACGEO
# 35           COF    COFACGEO
# 36           COF    COFACGEO
# 37           COF    COFACGEO
# 38           COF    COFACGEO
# 39           COF    COFACGEO
# 75           COI    COFACGEO
# 76           COI    COFACGEO
# 77           COI    COFACGEO
# 78           COI    COFACGEO
# 79           COI    COFACGEO
# 80           COI    COFACGEO
# 81           COI    COFACGEO
# 82           COI    COFACGEO
# 83           COI    COFACGEO
# 84           COI    COFACGEO
# 85           COJ    COFACGEO
# 86           COJ    COFACGEO
# 87           COJ    COFACGEO
# 88           COJ    COFACGEO
# 89           COJ    COFACGEO
# 90           COJ    COFACGEO
# 91           COJ    COFACGEO
# 92           COJ    COFACGEO
# 93           COJ    COFACGEO
# 94           COJ    COFACGEO
# 95           COK    COFACGEO
# 96           COK    COFACGEO
# 97           COK    COFACGEO
# 98           COK    COFACGEO
# 99           COK    COFACGEO
# 100          COK    COFACGEO
# 101          COK    COFACGEO
# 102          COK    COFACGEO
# 103          COK    COFACGEO
# 104          COK    COFACGEO
# 105          COL    COFACGEO
# 106          COL    COFACGEO
# 107          COL    COFACGEO
# 108          COL    COFACGEO
# 109          COL    COFACGEO
# 110          COL    COFACGEO
# 111          COL    COFACGEO
# 112          COL    COFACGEO
# 113          COL    COFACGEO
# 114          COL    COFACGEO
# 115          COM    COFACGEO
# 116          COM    COFACGEO
# 117          COM    COFACGEO
# 118          COM    COFACGEO
# 119          COM    COFACGEO
# 120          COM    COFACGEO
# 121          COM    COFACGEO
# 122          COM    COFACGEO
# 123          COM    COFACGEO
# 124          COM    COFACGEO
# 40           COG    COFACGEO
# 41           COG    COFACGEO
# 42           COG    COFACGEO
# 43           COG    COFACGEO
# 44           COG    COFACGEO
# 175          CON    COFACGEO
# 185          COO    COFACGEO
# 176          CON    COFACGEO
# 186          COO    COFACGEO
# 177          CON    COFACGEO
# 187          COO    COFACGEO
# 178          CON    COFACGEO
# 188          COO    COFACGEO
# 179          CON    COFACGEO
# 189          COO    COFACGEO
# 180          CON    COFACGEO
# 190          COO    COFACGEO
# 181          CON    COFACGEO
# 191          COO    COFACGEO
# 182          CON    COFACGEO
# 192          COO    COFACGEO
# 183          CON    COFACGEO
# 193          COO    COFACGEO
# 184          CON    COFACGEO
# 194          COO    COFACGEO
# 196          COP    COFACGEO
# 198          COQ    COFACGEO
# 200          COR    COFACGEO
# 203          COS    COFACGEO
# 208          COT    COFACGEO
# 210          COU    COFACGEO
# 211          COU    COFACGEO
# 197          COP    COFACGEO
# 199          COQ    COFACGEO
# 201          COR    COFACGEO
# 204          COS    COFACGEO
# 209          COT    COFACGEO
# 212          COU    COFACGEO
# 213          COU    COFACGEO
# 70           XX3    COFACGEO
# 71           XX3    COFACGEO
# 72           XX3    COFACGEO
# 73           XX3    COFACGEO
# 74           XX3    COFACGEO
# 45           COH    COFACGEO
# 46           COH    COFACGEO
# 47           COH    COFACGEO
# 48           COH    COFACGEO
# 49           COH    COFACGEO
# 165          COV    COFACGEO
# 166          COV    COFACGEO
# 167          COV    COFACGEO
# 168          COV    COFACGEO
# 169          COV    COFACGEO
# 170          COW    COFACGEO
# 171          COW    COFACGEO
# 172          COW    COFACGEO
# 173          COW    COFACGEO
# 174          COW    COFACGEO
# 50           COX    COFACGEO
# 51           COX    COFACGEO
# 52           COX    COFACGEO
# 53           COX    COFACGEO
# 54           COX    COFACGEO

# %%
dfFacFieldLookup.to_csv(os.path.join(dirResults,'CCSFactors_GeoAtypeVol_Lookup.csv'))
